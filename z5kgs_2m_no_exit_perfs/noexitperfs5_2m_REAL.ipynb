# %%
import numpy as np  #Importing NumPy4
import math
import matplotlib.pyplot as plt
import random
import matplotlib.ticker as ticker
import matplotlib
import pandas as pd
import platform

pwoa = pd.read_csv('noperfs_2m_CSV.csv')
pwo2a = pd.DataFrame(pwoa)
qstorage = pwo2a.to_numpy()
print(np.shape(qstorage))


pwo = pd.read_csv('noexitperfs5_2m_CSV.csv')
pwo2 = pd.DataFrame(pwo)
storage = pwo2.to_numpy()
print(np.shape(storage))

pwo3 = pd.read_csv('5kgs_2m_bothperfs_CSV.csv')
pwo23 = pd.DataFrame(pwo3)
storagew = pwo23.to_numpy()
print(np.shape(storagew))
# Out:
# (219, 143)
# (276, 143)
# (273, 143)

# %%
matplotlib.rcParams.update({'font.size': 20})
matplotlib.rcParams.update({'font.weight': 'bold'})


is_windows = any(platform.win32_ver())
if is_windows==True:
    path=r'CustomPath'
else:
    path=r'/Users/willba/Desktop'

fig = plt.figure(1)
ax = fig.gca()
for axis in [ax.xaxis, ax.yaxis]:
    axis.set_major_locator(ticker.MaxNLocator(integer=True))
fig.set_figwidth(18)
fig.set_figheight(18)

plt.plot(storagew[:,0]/86400,storagew[:,29],'r',marker = 'o',markersize = 11)
plt.plot(storage[:,0]/86400,storage[:,29],'r--',marker = '^',markersize = 11)
plt.plot(qstorage[:,0]/86400,qstorage[:,29],'r-.',marker = '*',markersize = 11)


#plt.xlim(0,0.5e6)
#plt.ylim(0,600)
plt.xlabel('Time (days)', fontsize = 20, fontweight = 'bold')
plt.ylabel('Pressure Drop (PSI)', fontsize = 20, fontweight = 'bold')
plt.title('Pressure Drop vs. Time (5 kg/s)',fontsize = 20, fontweight = 'bold')
plt.legend(['With Both Perfs','Without Exit Perfs','Without Any Perfs'], fontsize = 20)
plt.grid(which='major', axis='both',color='lightgrey',zorder=1)
fig.savefig(r'%s/noexitperfs55THMDeltaP.png' %path, bbox_inches='tight')

# %%
fig = plt.figure(1)
ax = fig.gca()
for axis in [ax.xaxis, ax.yaxis]:
    axis.set_major_locator(ticker.MaxNLocator(integer=True))
fig.set_figwidth(18)
fig.set_figheight(18)

plt.plot(storagew[:,0]/86400,(storagew[:,8]/1e6)*145.038,'r',marker = 'o',markersize = 11)
plt.plot(storage[:,0]/86400,(storage[:,8]/1e6)*145.038,'r--',marker = '^',markersize = 11)
plt.plot(qstorage[:,0]/86400,(qstorage[:,8]/1e6)*145.038,'r-.',marker = '*',markersize = 11)

plt.plot(storagew[:,0]/86400,(storagew[:,39]/1e6)*145.038,'b',marker = 'o',markersize = 11)
plt.plot(storage[:,0]/86400,(storage[:,39]/1e6)*145.038,'b--',marker = '^',markersize = 11)
plt.plot(qstorage[:,0]/86400,(qstorage[:,39]/1e6)*145.038,'b-.',marker = '*',markersize = 11)



#plt.xlim(0,10000)
#plt.ylim(0,400)
plt.xlabel('Time (days)', fontsize = 20, fontweight = 'bold')
plt.ylabel('Pressure (PSI)', fontsize = 20, fontweight = 'bold')
plt.title('Pressure vs. Time (5 kg/s)',fontsize = 20, fontweight = 'bold')
plt.legend(['Injection Pressure With Both Perfs','Injection Pressure Without Exit Perfs','Injection Pressure Without Any Perfs','Production Pressure With Both Perfs','Production Pressure Without Exit Perfs','Production Pressure Without Any Perfs'], fontsize = 20)
plt.grid(which='major', axis='both',color='lightgrey',zorder=1)
fig.savefig(r'%s/noexitperfs55THMP.png' %path, bbox_inches='tight')

# %%
fig = plt.figure(1)
ax = fig.gca()
#for axis in [ax.xaxis, ax.yaxis]:
#    axis.set_major_locator(ticker.MaxNLocator(integer=True))
fig.set_figwidth(18)
fig.set_figheight(18)
days = storage[:,0]/86400
daysw = storagew[:,0]/86400
qdays = qstorage[:,0]/86400


plt.plot(daysw,(storagew[:,9]/storagew[:,15])*100,'c',marker = 'o',markersize = 11)
plt.plot(days,(storage[:,9]/storage[:,15])*100,'c--',marker = '^',markersize = 11)
plt.plot(qdays,(qstorage[:,9]/qstorage[:,15])*100,'c-.',marker = '*',markersize = 11)

plt.plot(daysw,(storagew[:,11]/storagew[:,15])*100,'y',marker = 'o',markersize = 11)
plt.plot(days,(storage[:,11]/storage[:,15])*100,'y--',marker = '^',markersize = 11)
plt.plot(qdays,(qstorage[:,11]/qstorage[:,15])*100,'y-.',marker = '*',markersize = 11)

plt.plot(daysw,(storagew[:,13]/storagew[:,15])*100,'m',marker = 'o',markersize = 11)
plt.plot(days,(storage[:,13]/storage[:,15])*100,'m--',marker = '^',markersize = 11)
plt.plot(qdays,(qstorage[:,13]/qstorage[:,15])*100,'m-.',marker = '*',markersize = 11)
plt.hlines(100/3, -1, 12, colors='r', linestyles='solid',zorder=3)
#plt.hlines(-25, -1, 12, colors='k', linestyles='solid',zorder=3)
#plt.hlines(0, -1, 12, colors='k', linestyles='solid',zorder=3)
#plt.hlines(25, -1, 12, colors='k', linestyles='solid',zorder=3)
#plt.hlines(50, -1, 12, colors='k', linestyles='solid',zorder=3)
#plt.hlines(75, -1, 12, colors='k', linestyles='solid',zorder=3)
#plt.hlines(100, -1, 12, colors='k', linestyles='solid',zorder=3)
#plt.hlines(125, -1, 12, colors='k', linestyles='solid',zorder=3)

#plt.plot(storage[:,0],storage[:,7],'b',marker = 'o',markersize = 11)
#plt.plot(storage[:,0],storage[:,8],'k',marker = 'o',markersize = 11)
#plt.plot(storage[:,0],storage[:,9],'k',marker = 'o',markersize = 11)
#plt.plot(storage[:,0],storage[:,10],'k',marker = 'o',markersize = 11)



#ax.set_yticks(range(-200,200,10))
#ax.yaxis.grid(True,which = 'major',color = 'k', linestyle = '-')
#ax.yaxis.grid(True,which = 'minor',color = 'k', linestyle = '--')
ax.set_yticks(range(-25,150,25))

for ymaj in ax.yaxis.get_majorticklocs():
  ax.axhline(y=ymaj, ls='-',color = 'k')
for ymin in ax.yaxis.get_minorticklocs():
  ax.axhline(y=ymin, ls='--',color = 'k')


#plt.xlim(45000,1e6)
plt.ylim(-25,125)
plt.xlabel('Time (days)', fontsize = 20, fontweight = 'bold')
plt.ylabel('Flow Distribution (%)', fontsize = 20, fontweight = 'bold')
plt.title('Flow Distribution vs. Time (5 kg/s)',fontsize = 20, fontweight = 'bold')
plt.legend(['Fracture1 With Both Perfs','Fracture1 Without Exit Perfs','Fracture1 Without Any Perfs','Fracture2 With Both Perfs','Fracture2 Without Exit Perfs','Fracture2 Without Any Perfs','Fracture3 With Both Perfs','Fracture3 Without Exit Perfs','Fracture3 Without Any Perfs','Ideal Distribution'], fontsize = 20)
plt.grid(which='major', axis='both',color='lightgrey',zorder=1)
fig.savefig(r'%s/noexitperfs55THMmass.png' %path, bbox_inches='tight')
# Out:
# /var/folders/3r/f488tfdd35l_ymz1rh2v2ts8g1rj13/T/ipykernel_7633/3917163246.py:12: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(daysw,(storagew[:,9]/storagew[:,15])*100,'c',marker = 'o',markersize = 11)
# /var/folders/3r/f488tfdd35l_ymz1rh2v2ts8g1rj13/T/ipykernel_7633/3917163246.py:13: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(days,(storage[:,9]/storage[:,15])*100,'c--',marker = '^',markersize = 11)
# /var/folders/3r/f488tfdd35l_ymz1rh2v2ts8g1rj13/T/ipykernel_7633/3917163246.py:14: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(qdays,(qstorage[:,9]/qstorage[:,15])*100,'c-.',marker = '*',markersize = 11)
# /var/folders/3r/f488tfdd35l_ymz1rh2v2ts8g1rj13/T/ipykernel_7633/3917163246.py:16: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(daysw,(storagew[:,11]/storagew[:,15])*100,'y',marker = 'o',markersize = 11)
# /var/folders/3r/f488tfdd35l_ymz1rh2v2ts8g1rj13/T/ipykernel_7633/3917163246.py:17: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(days,(storage[:,11]/storage[:,15])*100,'y--',marker = '^',markersize = 11)
# /var/folders/3r/f488tfdd35l_ymz1rh2v2ts8g1rj13/T/ipykernel_7633/3917163246.py:18: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(qdays,(qstorage[:,11]/qstorage[:,15])*100,'y-.',marker = '*',markersize = 11)
# /var/folders/3r/f488tfdd35l_ymz1rh2v2ts8g1rj13/T/ipykernel_7633/3917163246.py:20: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(daysw,(storagew[:,13]/storagew[:,15])*100,'m',marker = 'o',markersize = 11)
# /var/folders/3r/f488tfdd35l_ymz1rh2v2ts8g1rj13/T/ipykernel_7633/3917163246.py:21: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(days,(storage[:,13]/storage[:,15])*100,'m--',marker = '^',markersize = 11)
# /var/folders/3r/f488tfdd35l_ymz1rh2v2ts8g1rj13/T/ipykernel_7633/3917163246.py:22: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(qdays,(qstorage[:,13]/qstorage[:,15])*100,'m-.',marker = '*',markersize = 11)

# %%
fig = plt.figure(1)
ax = fig.gca()
for axis in [ax.xaxis, ax.yaxis]:
    axis.set_major_locator(ticker.MaxNLocator(integer=True))
fig.set_figwidth(18)
fig.set_figheight(18)



plt.plot(storagew[:,0]/86400,storagew[:,15],'c',marker = 'o',markersize = 11)
plt.plot(storagew[:,0]/86400,storagew[:,16],'y',marker = 'o',markersize = 11)

plt.plot(storage[:,0]/86400,storage[:,15],'c--',marker = '^',markersize = 11)
plt.plot(storage[:,0]/86400,storage[:,16],'y--',marker = '^',markersize = 11)

plt.plot(qstorage[:,0]/86400,qstorage[:,15],'c-.',marker = '*',markersize = 11)
plt.plot(qstorage[:,0]/86400,qstorage[:,16],'y-.',marker = '*',markersize = 11)


#plt.xlim(45000,1e6)
plt.ylim(0,6)
plt.xlabel('Time (days)', fontsize = 20, fontweight = 'bold')
plt.ylabel('Flow Rate (kg/s)', fontsize = 20, fontweight = 'bold')
plt.title('Flow Rate vs. Time (5 kg/s)',fontsize = 20, fontweight = 'bold')
plt.legend(['Inlet With Both Perfs','Outlet With Both Perfs','Inlet Without Exit Perfs','Outlet Without Exit Perfs','Inlet Without Any Perfs','Outlet Without Any Perfs'], fontsize = 20)
plt.grid(which='major', axis='both',color='lightgrey',zorder=1)
fig.savefig(r'%s/noexitperfs55THMmasscheck.png' %path, bbox_inches='tight')

# %%
fig = plt.figure(1)
ax = fig.gca()
for axis in [ax.xaxis, ax.yaxis]:
    axis.set_major_locator(ticker.MaxNLocator(integer=True))
fig.set_figwidth(18)
fig.set_figheight(18)

plt.plot(storagew[:,0]/86400,storagew[:,23],'c',marker = 'o',markersize = 11)
plt.plot(storage[:,0]/86400,storage[:,23],'c--',marker = '^',markersize = 11)
plt.plot(qstorage[:,0]/86400,qstorage[:,23],'c-.',marker = '*',markersize = 11)

plt.plot(storagew[:,0]/86400,storagew[:,25],'y',marker = 'o',markersize = 11)
plt.plot(storage[:,0]/86400,storage[:,25],'y--',marker = '^',markersize = 11)
plt.plot(qstorage[:,0]/86400,qstorage[:,25],'y-.',marker = '*',markersize = 11)

plt.plot(storagew[:,0]/86400,storagew[:,27],'m',marker = 'o',markersize = 11)
plt.plot(storage[:,0]/86400,storage[:,27],'m--',marker = '^',markersize = 11)
plt.plot(qstorage[:,0]/86400,qstorage[:,27],'m-.',marker = '*',markersize = 11)



#plt.xlim(45000,1e6)
plt.ylim(-0.3e-10,0.1e-9)
plt.xlabel('Time (days)', fontsize = 20, fontweight = 'bold')
plt.ylabel('Permeability (m^2)', fontsize = 20, fontweight = 'bold')
plt.title('Permeability vs. Time (5 kg/s)',fontsize = 20, fontweight = 'bold')
plt.legend(['Fracture1 With Both Perfs','Fracture1 Without Exit Perfs','Fracture1 Without Any Perfs','Fracture2 With Both Perfs','Fracture2 Without Exit Perfs','Fracture2 Without Any Perfs','Fracture3 With Both Perfs','Fracture3 Without Exit Perfs','Fracture3 Without Any Perfs'], fontsize = 20)
plt.grid(which='major', axis='both',color='lightgrey',zorder=1)
fig.savefig(r'%s/noexitperfs55THMpermeability.png' %path, bbox_inches='tight')

# %%
fig = plt.figure(1)
ax = fig.gca()
for axis in [ax.xaxis, ax.yaxis]:
    axis.set_major_locator(ticker.MaxNLocator(integer=True))
fig.set_figwidth(18)
fig.set_figheight(18)

plt.plot(storagew[:,0]/86400,storagew[:,30],'c',marker = 'o',markersize = 11)
plt.plot(storage[:,0]/86400,storage[:,30],'c--',marker = '^',markersize = 11)
plt.plot(qstorage[:,0]/86400,qstorage[:,30],'c-.',marker = '*',markersize = 11)

plt.plot(storagew[:,0]/86400,storagew[:,31],'y',marker = 'o',markersize = 11)
plt.plot(storage[:,0]/86400,storage[:,31],'y--',marker = '^',markersize = 11)
plt.plot(qstorage[:,0]/86400,qstorage[:,31],'y-.',marker = '*',markersize = 11)

plt.plot(storagew[:,0]/86400,storagew[:,32],'m',marker = 'o',markersize = 11)
plt.plot(storage[:,0]/86400,storage[:,32],'m--',marker = '^',markersize = 11)
plt.plot(qstorage[:,0]/86400,qstorage[:,32],'m-.',marker = '*',markersize = 11)




#plt.xlim(45000,1e6)
#plt.ylim(0,100)
plt.xlabel('Time (days)', fontsize = 20, fontweight = 'bold')
plt.ylabel('Pressure Drop (PSI)', fontsize = 20, fontweight = 'bold')
plt.title('Pressure Drop vs. Time (5 kg/s)',fontsize = 20, fontweight = 'bold')
plt.legend(['Fracture1 With Both Perfs','Fracture1 Without Exit Perfs','Fracture1 Without Any Perfs','Fracture2 With Both Perfs','Fracture2 Without Exit Perfs','Fracture2 Without Any Perfs','Fracture3 With Both Perfs','Fracture3 Without Exit Perfs','Fracture3 Without Any Perfs'], fontsize = 20)
plt.grid(which='major', axis='both',color='lightgrey',zorder=1)
fig.savefig(r'%s/noexitperfs55THMdeltaPfractures.png' %path, bbox_inches='tight')

# %%
fig = plt.figure(1)
ax = fig.gca()
for axis in [ax.xaxis, ax.yaxis]:
    axis.set_major_locator(ticker.MaxNLocator(integer=True))
fig.set_figwidth(18)
fig.set_figheight(18)




plt.plot(storage[:,0]/86400,storage[:,2]-273.15,'c',marker = 'o',markersize = 11)
plt.plot(storage[:,0]/86400,storage[:,3]-273.15,'c--',marker = '^',markersize = 11)
plt.plot(storage[:,0]/86400,storage[:,4]-273.15,'y',marker = 'o',markersize = 11)
plt.plot(storage[:,0]/86400,storage[:,5]-273.15,'y--',marker = '^',markersize = 11)
plt.plot(storage[:,0]/86400,storage[:,6]-273.15,'m',marker = 'o',markersize = 11)
plt.plot(storage[:,0]/86400,storage[:,7]-273.15,'m--',marker = '^',markersize = 11)








#plt.xlim(45000,1e6)
#plt.ylim(0,6)
plt.xlabel('Time (days)', fontsize = 20, fontweight = 'bold')
plt.ylabel('Temperature (°C)', fontsize = 20, fontweight = 'bold')
plt.title('Temperature vs. Time (5 kg/s) (No Exit Perfs)',fontsize = 20, fontweight = 'bold')
plt.legend(['Fracture1 Inlet','Fracture1 Outlet','Fracture2 Inlet','Fracture2 Outlet','Fracture3 Inlet','Fracture3 Outlet'], fontsize = 20)
plt.grid(which='major', axis='both',color='lightgrey',zorder=1)
fig.savefig(r'%s/noexitperfs55THMtemp.png' %path, bbox_inches='tight')

# %%
fig = plt.figure(1)
ax = fig.gca()
for axis in [ax.xaxis, ax.yaxis]:
    axis.set_major_locator(ticker.MaxNLocator(integer=True))
fig.set_figwidth(18)
fig.set_figheight(18)




plt.plot(storagew[:,0]/86400,storagew[:,2]-273.15,'c',marker = 'o',markersize = 11)
plt.plot(storagew[:,0]/86400,storagew[:,3]-273.15,'c--',marker = '^',markersize = 11)
plt.plot(storagew[:,0]/86400,storagew[:,4]-273.15,'y',marker = 'o',markersize = 11)
plt.plot(storagew[:,0]/86400,storagew[:,5]-273.15,'y--',marker = '^',markersize = 11)
plt.plot(storagew[:,0]/86400,storagew[:,6]-273.15,'m',marker = 'o',markersize = 11)
plt.plot(storagew[:,0]/86400,storagew[:,7]-273.15,'m--',marker = '^',markersize = 11)








#plt.xlim(45000,1e6)
#plt.ylim(0,6)
plt.xlabel('Time (days)', fontsize = 20, fontweight = 'bold')
plt.ylabel('Temperature (°C)', fontsize = 20, fontweight = 'bold')
plt.title('Temperature vs. Time (5 kg/s) (With Both Perfs)',fontsize = 20, fontweight = 'bold')
plt.legend(['Fracture1 Inlet','Fracture1 Outlet','Fracture2 Inlet','Fracture2 Outlet','Fracture3 Inlet','Fracture3 Outlet'], fontsize = 20)
plt.grid(which='major', axis='both',color='lightgrey',zorder=1)
fig.savefig(r'%s/withbothperfs55THMtemp.png' %path, bbox_inches='tight')

# %%
fig = plt.figure(1)
ax = fig.gca()
for axis in [ax.xaxis, ax.yaxis]:
    axis.set_major_locator(ticker.MaxNLocator(integer=True))
fig.set_figwidth(18)
fig.set_figheight(18)




plt.plot(qstorage[:,0]/86400,qstorage[:,2]-273.15,'c',marker = 'o',markersize = 11)
plt.plot(qstorage[:,0]/86400,qstorage[:,3]-273.15,'c--',marker = '^',markersize = 11)
plt.plot(qstorage[:,0]/86400,qstorage[:,4]-273.15,'y',marker = 'o',markersize = 11)
plt.plot(qstorage[:,0]/86400,qstorage[:,5]-273.15,'y--',marker = '^',markersize = 11)
plt.plot(qstorage[:,0]/86400,qstorage[:,6]-273.15,'m',marker = 'o',markersize = 11)
plt.plot(qstorage[:,0]/86400,qstorage[:,7]-273.15,'m--',marker = '^',markersize = 11)








#plt.xlim(45000,1e6)
#plt.ylim(0,6)
plt.xlabel('Time (days)', fontsize = 20, fontweight = 'bold')
plt.ylabel('Temperature (°C)', fontsize = 20, fontweight = 'bold')
plt.title('Temperature vs. Time (5 kg/s) (Without Any Perfs)',fontsize = 20, fontweight = 'bold')
plt.legend(['Fracture1 Inlet','Fracture1 Outlet','Fracture2 Inlet','Fracture2 Outlet','Fracture3 Inlet','Fracture3 Outlet'], fontsize = 20)
plt.grid(which='major', axis='both',color='lightgrey',zorder=1)
fig.savefig(r'%s/noanyperfs55THMtemp.png' %path, bbox_inches='tight')

# %%
fig = plt.figure(1)
ax = fig.gca()
for axis in [ax.xaxis, ax.yaxis]:
    axis.set_major_locator(ticker.MaxNLocator(integer=True))
fig.set_figwidth(18)
fig.set_figheight(18)

plt.plot(storage[:,0]/86400,storage[:,46],'r',marker = 'o',markersize = 11)


#plt.xlim(0,31)
#plt.ylim(0,2000)
plt.xlabel('Time (days)', fontsize = 20, fontweight = 'bold')
plt.ylabel('Exit Velocity (m/s)', fontsize = 20, fontweight = 'bold')
plt.title('Exit Velocity vs. Time (5 kg/s)',fontsize = 20, fontweight = 'bold')
#plt.legend(['Injection Pressure','Production Pressure'], fontsize = 20)
plt.grid(which='major', axis='both',color='lightgrey',zorder=1)
fig.savefig(r'%s/noexitperfs55THMRe.png' %path, bbox_inches='tight')

# %%
pwo = pd.read_csv('noexitperfs5_CSV_injection_pipe_p_0242.csv')
pwo2 = pd.DataFrame(pwo)
injection = pwo2.to_numpy()
print(np.shape(injection))

pwoa = pd.read_csv('noexitperfs5_CSV_pipe2_p_0316.csv')
pwo2a = pd.DataFrame(pwoa)
pipe2 = pwo2a.to_numpy()

pwoa5 = pd.read_csv('noexitperfs5_CSV_fracture1_perf1_p_0316.csv')
pwo2a5 = pd.DataFrame(pwoa5)
frac1_perf1 = pwo2a5.to_numpy()

pwoa57 = pd.read_csv('noexitperfs5_CSV_fracture1_perf2_p_0316.csv')
pwo2a57 = pd.DataFrame(pwoa57)
frac1_perf2 = pwo2a57.to_numpy()

pwoa574 = pd.read_csv('noexitperfs5_CSV_fracture1_p_0316.csv')
pwo2a574 = pd.DataFrame(pwoa574)
frac1 = pwo2a574.to_numpy()

pwoa5b = pd.read_csv('noexitperfs5_CSV_fracture2_perf1_p_0316.csv')
pwo2a5b = pd.DataFrame(pwoa5b)
frac2_perf1 = pwo2a5b.to_numpy()

pwoa57b = pd.read_csv('noexitperfs5_CSV_fracture2_perf2_p_0316.csv')
pwo2a57b = pd.DataFrame(pwoa57b)
frac2_perf2 = pwo2a57b.to_numpy()

pwoa574b = pd.read_csv('noexitperfs5_CSV_fracture2_p_0316.csv')
pwo2a574b = pd.DataFrame(pwoa574b)
frac2 = pwo2a574b.to_numpy()

pwoa574bc = pd.read_csv('noexitperfs5_CSV_fracture3_p_0316.csv')
pwo2a574bc = pd.DataFrame(pwoa574bc)
frac3 = pwo2a574bc.to_numpy()

pwob = pd.read_csv('noexitperfs5_CSV_pipe3_p_0316.csv')
pwo2b = pd.DataFrame(pwob)
pipe3 = pwo2b.to_numpy()

pwoc = pd.read_csv('noexitperfs5_CSV_pipe4_p_0316.csv')
pwo2c = pd.DataFrame(pwoc)
pipe4 = pwo2c.to_numpy()

pwod = pd.read_csv('noexitperfs5_CSV_pipe5_p_0316.csv')
pwo2d = pd.DataFrame(pwod)
pipe5 = pwo2d.to_numpy()

pwoe = pd.read_csv('noexitperfs5_CSV_pipe6_p_0316.csv')
pwo2e = pd.DataFrame(pwoe)
pipe6 = pwo2e.to_numpy()

pwoe3 = pd.read_csv('noexitperfs5_CSV_pipe7_p_0316.csv')
pwo2e3 = pd.DataFrame(pwoe3)
pipe7 = pwo2e3.to_numpy()

pwoz = pd.read_csv('noexitperfs5_CSV_production_pipe_p_0316.csv')
pwo2z = pd.DataFrame(pwoz)
production = pwo2z.to_numpy()
# Out:
# (200, 5)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [87], in <cell line: 6>()
#       3 injection = pwo2.to_numpy()
#       4 print(np.shape(injection))
# ----> 6 pwoa = pd.read_csv('noexitperfs5_CSV_pipe2_p_0316.csv')
#       7 pwo2a = pd.DataFrame(pwoa)
#       8 pipe2 = pwo2a.to_numpy()
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:933, in TextFileReader.__init__(self, f, engine, **kwds)
#     930     self.options["has_index_names"] = kwds["has_index_names"]
#     932 self.handles: IOHandles | None = None
# --> 933 self._engine = self._make_engine(f, self.engine)
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1217, in TextFileReader._make_engine(self, f, engine)
#    1213     mode = "rb"
#    1214 # error: No overload variant of "get_handle" matches argument types
#    1215 # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1216 # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1217 self.handles = get_handle(  # type: ignore[call-overload]
#    1218     f,
#    1219     mode,
#    1220     encoding=self.options.get("encoding", None),
#    1221     compression=self.options.get("compression", None),
#    1222     memory_map=self.options.get("memory_map", False),
#    1223     is_text=is_text,
#    1224     errors=self.options.get("encoding_errors", "strict"),
#    1225     storage_options=self.options.get("storage_options", None),
#    1226 )
#    1227 assert self.handles is not None
#    1228 f = self.handles.handle
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/io/common.py:789, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784 elif isinstance(handle, str):
#     785     # Check whether the filename is to be opened in binary mode.
#     786     # Binary mode does not support 'encoding' and 'newline'.
#     787     if ioargs.encoding and "b" not in ioargs.mode:
#     788         # Encoding
# --> 789         handle = open(
#     790             handle,
#     791             ioargs.mode,
#     792             encoding=ioargs.encoding,
#     793             errors=errors,
#     794             newline="",
#     795         )
#     796     else:
#     797         # Binary mode
#     798         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'noexitperfs5_CSV_pipe2_p_0316.csv'

# %%
fig = plt.figure(1)

matplotlib.rcParams.update({'font.size': 20})
matplotlib.rcParams.update({'font.weight': 'bold'})
ax = fig.gca()
for axis in [ax.xaxis, ax.yaxis]:
    axis.set_major_locator(ticker.MaxNLocator(integer=True))
fig.set_figwidth(18)
fig.set_figheight(18)

plt.plot(injection[:,0],(injection[:,1]/1e6)*145.038,'r',marker = 'o',markersize = 11)
plt.plot(2057+pipe2[:,0],(pipe2[:,1]/1e6)*145.038,'b',marker = 'o',markersize = 11)

plt.plot(2057+1030.624+pipe3[:,0],(pipe3[:,1]/1e6)*145.038,'g',marker = 'o',markersize = 11)


plt.plot(2057+1030.624+134.11199999999977579826999+pipe4[:,0],(pipe4[:,1]/1e6)*145.038,'y',marker = 'o',markersize = 11)




#plt.xlim(0,31)
#plt.ylim(4800,5400)
plt.xlabel('Length (m)', fontsize = 20, fontweight = 'bold')
plt.ylabel('Pressure (PSI)', fontsize = 20, fontweight = 'bold')
plt.title('Length vs. Pressure (~= 11 days) (5 kg/s)',fontsize = 20, fontweight = 'bold')
plt.legend(['Injection Pipe','pipe2','pipe3','pipe4'], fontsize = 20)
plt.grid(which='major', axis='both',color='lightgrey',zorder=1)
fig.savefig(r'%s/noexitperfs55InjectionP.png' %path, bbox_inches='tight')

# %%
fig = plt.figure(1)

matplotlib.rcParams.update({'font.size': 20})
matplotlib.rcParams.update({'font.weight': 'bold'})
ax = fig.gca()
for axis in [ax.xaxis, ax.yaxis]:
    axis.set_major_locator(ticker.MaxNLocator(integer=True))
fig.set_figwidth(18)
fig.set_figheight(18)

plt.plot(injection[:,0],(injection[:,1]/1e6)*145.038,'r',marker = 'o',markersize = 11)
plt.plot(2057+pipe2[:,0],(pipe2[:,1]/1e6)*145.038,'b',marker = 'o',markersize = 11)
plt.plot(2057+1030.624+pipe3[:,0],(pipe3[:,1]/1e6)*145.038,'g',marker = 'o',markersize = 11)
plt.plot(2057+1030.624+134.11199999999977579826999+pipe4[:,0],(pipe4[:,1]/1e6)*145.038,'c',marker = 'o',markersize = 11)
plt.plot(2057+1030.624+134.11199999999977579826999+96.6216000000002242017300066403672380476882366854447151848085862086006951628994154778073990218053823121593587821581875667170042568+frac3[:,0],(frac3[:,1]/1e6)*145.038,'m',marker = 'o',markersize = 11)
plt.plot(2057+1030.624+134.11199999999977579826999+96.6216000000002242017300066403672380476882366854447151848085862086006951628994154778073990218053823121593587821581875667170042568+100+pipe5[:,0],(pipe5[:,1]/1e6)*145.038,color = '0.8',marker = 'o',markersize = 11)
plt.plot(2057+1030.624+134.11199999999977579826999+96.6216000000002242017300066403672380476882366854447151848085862086006951628994154778073990218053823121593587821581875667170042568+100+95.98796573232744884430750078506290102503278647382158534085570989394969673954105727357396694128582740674997664529042836849765532463+pipe6[:,0],(pipe6[:,1]/1e6)*145.038,'k',marker = 'o',markersize = 11)
plt.plot(2057+1030.624+134.11199999999977579826999+96.6216000000002242017300066403672380476882366854447151848085862086006951628994154778073990218053823121593587821581875667170042568+100+95.98796573232744884430750078506290102503278647382158534085570989394969673954105727357396694128582740674997664529042836849765532463+134.38315202540329451498066+pipe7[:,0],(pipe7[:,1]/1e6)*145.038,'b--',marker = '^',markersize = 11)
plt.plot(2057+1030.624+134.11199999999977579826999+96.6216000000002242017300066403672380476882366854447151848085862086006951628994154778073990218053823121593587821581875667170042568+100+95.98796573232744884430750078506290102503278647382158534085570989394969673954105727357396694128582740674997664529042836849765532463+134.38315202540329451498066+1029.81374664313154979060373785491118567+production[:,0],(production[:,1]/1e6)*145.038,'r--',marker = '^',markersize = 11)

plt.plot(2057+1030.624+frac1_perf1[:,0],(frac1_perf1[:,1]/1e6)*145.038,'c--',marker = '^',markersize = 11)
plt.plot(2057+1030.624+1+frac1[:,0],(frac1[:,1]/1e6)*145.038,'c--',marker = '^',markersize = 11)

plt.plot(2057+1030.624+1+98.06447557162307005210248929005225739881232750283853044679409922670562628737052780066190947088625665447598227063665130067648666298+frac1_perf2[:,0],(frac1_perf2[:,1]/1e6)*145.038,'c--',marker = '^',markersize = 11)

plt.plot(2057+1030.624+134.11199999999977579826999+frac2_perf1[:,0],(frac2_perf1[:,1]/1e6)*145.038,'y--',marker = '^',markersize = 11)
plt.plot(2057+1030.624+134.11199999999977579826999+1+frac2[:,0],(frac2[:,1]/1e6)*145.038,'y--',marker = '^',markersize = 11)

plt.plot(2057+1030.624+134.11199999999977579826999+1+97.90155581456182682116814463820372338+frac2_perf2[:,0],(frac2_perf2[:,1]/1e6)*145.038,'y--',marker = '^',markersize = 11)



plt.hlines((frac1_perf2[199,1]/1e6)*145.038, 3200, 3630, colors='c', linestyles='dashed',zorder=3)
plt.hlines((frac2_perf2[199,1]/1e6)*145.038, 3310, 3510, colors='y', linestyles='dashed',zorder=3)

print(frac1_perf2[199,1]-pipe7[0,1])
print(frac2_perf2[199,1]-pipe6[0,1])


#plt.xlim(0,31)
#plt.ylim(4800,5400)
plt.xlabel('Length (m)', fontsize = 20, fontweight = 'bold')
plt.ylabel('Pressure (PSI)', fontsize = 20, fontweight = 'bold')
plt.title('Length vs. Pressure (~= 11 days) (5 kg/s)',fontsize = 20, fontweight = 'bold')
plt.legend(['Injection Pipe','pipe2','pipe3','pipe4','fracture3','pipe5','pipe6','pipe7','Production Pipe','fracture1_perf1','fracture1','fracture1_perf2','fracture2_perf1','fracture2','fracture2_perf2'], fontsize = 20)
plt.grid(which='major', axis='both',color='lightgrey',zorder=1)
fig.savefig(r'%s/noexitperfs55THMlengthfrac3.png' %path, bbox_inches='tight')
