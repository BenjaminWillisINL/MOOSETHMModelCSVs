# %%
import numpy as np  #Importing NumPy4
import math
import matplotlib.pyplot as plt
import random
import matplotlib.ticker as ticker
import matplotlib
import pandas as pd
import platform

#pwoa = pd.read_csv('1fracmodel_CSV.csv')
#pwo2a = pd.DataFrame(pwoa)
#qstorage = pwo2a.to_numpy()
#print(np.shape(qstorage))


#pwo = pd.read_csv('noexitperfs5_1m_CSV.csv')
#pwo2 = pd.DataFrame(pwo)
#storage = pwo2.to_numpy()
#print(np.shape(storage))

pwo3 = pd.read_csv('1fracmodel_CSV.csv')
pwo23 = pd.DataFrame(pwo3)
storagew = pwo23.to_numpy()
print(np.shape(storagew))
# Out:
# (159, 101)

# %%
matplotlib.rcParams.update({'font.size': 20})
matplotlib.rcParams.update({'font.weight': 'bold'})


is_windows = any(platform.win32_ver())
if is_windows==True:
    path=r'CustomPath'
else:
    path=r'/Users/willba/Desktop'

fig = plt.figure(1)
ax = fig.gca()
for axis in [ax.xaxis, ax.yaxis]:
    axis.set_major_locator(ticker.MaxNLocator(integer=True))
fig.set_figwidth(18)
fig.set_figheight(18)

plt.plot(storagew[:,0]/86400,storagew[:,13],'r',marker = 'o',markersize = 11)
#plt.plot(storage[:,0]/86400,storage[:,13],'r--',marker = '^',markersize = 11)
#plt.plot(qstorage[:,0]/86400,qstorage[:,13],'r-.',marker = '*',markersize = 11)


#plt.xlim(0,0.5e6)
#plt.ylim(0,600)
plt.xlabel('Time (days)', fontsize = 20, fontweight = 'bold')
plt.ylabel('Pressure Drop (PSI)', fontsize = 20, fontweight = 'bold')
plt.title('Pressure Drop vs. Time (5 kg/s) (One Fracture Model)',fontsize = 20, fontweight = 'bold')
#plt.legend(['With Both Perfs','Without Exit Perfs','Without Any Perfs'], fontsize = 20)
plt.grid(which='major', axis='both',color='lightgrey',zorder=1)
fig.savefig(r'%s/1fracmodelTHMDeltaP.png' %path, bbox_inches='tight')

# %%
fig = plt.figure(1)
ax = fig.gca()
for axis in [ax.xaxis, ax.yaxis]:
    axis.set_major_locator(ticker.MaxNLocator(integer=True))
fig.set_figwidth(18)
fig.set_figheight(18)

plt.plot(storagew[:,0]/86400,(storagew[:,4]/1e6)*145.038,'r',marker = 'o',markersize = 11)
#plt.plot(storage[:,0]/86400,(storage[:,8]/1e6)*145.038,'r--',marker = '^',markersize = 11)
#plt.plot(qstorage[:,0]/86400,(qstorage[:,8]/1e6)*145.038,'r-.',marker = '*',markersize = 11)

plt.plot(storagew[:,0]/86400,(storagew[:,17]/1e6)*145.038,'b',marker = 'o',markersize = 11)
#plt.plot(storage[:,0]/86400,(storage[:,39]/1e6)*145.038,'b--',marker = '^',markersize = 11)
#plt.plot(qstorage[:,0]/86400,(qstorage[:,39]/1e6)*145.038,'b-.',marker = '*',markersize = 11)



#plt.xlim(0,10000)
#plt.ylim(0,400)
plt.xlabel('Time (days)', fontsize = 20, fontweight = 'bold')
plt.ylabel('Pressure (PSI)', fontsize = 20, fontweight = 'bold')
plt.title('Pressure vs. Time (5 kg/s) (One Fracture Model)',fontsize = 20, fontweight = 'bold')
plt.legend(['Injection Pressure','Production Pressure'], fontsize = 20)
plt.grid(which='major', axis='both',color='lightgrey',zorder=1)
fig.savefig(r'%s/1fracmodelTHMP.png' %path, bbox_inches='tight')

# %%
fig = plt.figure(1)
ax = fig.gca()
#for axis in [ax.xaxis, ax.yaxis]:
#    axis.set_major_locator(ticker.MaxNLocator(integer=True))
fig.set_figwidth(18)
fig.set_figheight(18)
#days = storage[:,0]/86400
daysw = storagew[:,0]/86400
#qdays = qstorage[:,0]/86400


plt.plot(daysw,(storagew[:,5]/storagew[:,7])*100,'c',marker = 'o',markersize = 11)
#plt.plot(days,(storage[:,9]/storage[:,15])*100,'c--',marker = '^',markersize = 11)
#plt.plot(qdays,(qstorage[:,9]/qstorage[:,15])*100,'c-.',marker = '*',markersize = 11)

#plt.plot(daysw,(storagew[:,11]/storagew[:,15])*100,'y',marker = 'o',markersize = 11)
#plt.plot(days,(storage[:,11]/storage[:,15])*100,'y--',marker = '^',markersize = 11)
#plt.plot(qdays,(qstorage[:,11]/qstorage[:,15])*100,'y-.',marker = '*',markersize = 11)

#plt.plot(daysw,(storagew[:,13]/storagew[:,15])*100,'m',marker = 'o',markersize = 11)
#plt.plot(days,(storage[:,13]/storage[:,15])*100,'m--',marker = '^',markersize = 11)
#plt.plot(qdays,(qstorage[:,13]/qstorage[:,15])*100,'m-.',marker = '*',markersize = 11)
#plt.hlines(100/3, -1, 12, colors='r', linestyles='solid',zorder=3)
#plt.hlines(-25, -1, 12, colors='k', linestyles='solid',zorder=3)
#plt.hlines(0, -1, 12, colors='k', linestyles='solid',zorder=3)
#plt.hlines(25, -1, 12, colors='k', linestyles='solid',zorder=3)
#plt.hlines(50, -1, 12, colors='k', linestyles='solid',zorder=3)
#plt.hlines(75, -1, 12, colors='k', linestyles='solid',zorder=3)
#plt.hlines(100, -1, 12, colors='k', linestyles='solid',zorder=3)
#plt.hlines(125, -1, 12, colors='k', linestyles='solid',zorder=3)

#plt.plot(storage[:,0],storage[:,7],'b',marker = 'o',markersize = 11)
#plt.plot(storage[:,0],storage[:,8],'k',marker = 'o',markersize = 11)
#plt.plot(storage[:,0],storage[:,9],'k',marker = 'o',markersize = 11)
#plt.plot(storage[:,0],storage[:,10],'k',marker = 'o',markersize = 11)



#ax.set_yticks(range(-200,200,10))
#ax.yaxis.grid(True,which = 'major',color = 'k', linestyle = '-')
#ax.yaxis.grid(True,which = 'minor',color = 'k', linestyle = '--')
ax.set_yticks(range(-25,150,25))

for ymaj in ax.yaxis.get_majorticklocs():
  ax.axhline(y=ymaj, ls='-',color = 'k')
for ymin in ax.yaxis.get_minorticklocs():
  ax.axhline(y=ymin, ls='--',color = 'k')


#plt.xlim(45000,1e6)
plt.ylim(-25,125)
plt.xlabel('Time (days)', fontsize = 20, fontweight = 'bold')
plt.ylabel('Flow Distribution (%)', fontsize = 20, fontweight = 'bold')
plt.title('Flow Distribution vs. Time (5 kg/s) (One Fracture Model)',fontsize = 20, fontweight = 'bold')
#plt.legend(['Fracture1 With Both Perfs','Fracture1 Without Exit Perfs','Fracture1 Without Any Perfs','Fracture2 With Both Perfs','Fracture2 Without Exit Perfs','Fracture2 Without Any Perfs','Fracture3 With Both Perfs','Fracture3 Without Exit Perfs','Fracture3 Without Any Perfs','Ideal Distribution'], fontsize = 20)
plt.grid(which='major', axis='both',color='lightgrey',zorder=1)
fig.savefig(r'%s/1fracmodelTHMmass.png' %path, bbox_inches='tight')
# Out:
# /var/folders/3r/f488tfdd35l_ymz1rh2v2ts8g1rj13/T/ipykernel_92763/1928313181.py:12: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(daysw,(storagew[:,5]/storagew[:,7])*100,'c',marker = 'o',markersize = 11)

# %%
fig = plt.figure(1)
ax = fig.gca()
for axis in [ax.xaxis, ax.yaxis]:
    axis.set_major_locator(ticker.MaxNLocator(integer=True))
fig.set_figwidth(18)
fig.set_figheight(18)



plt.plot(storagew[:,0]/86400,storagew[:,7],'c',marker = 'o',markersize = 11)
plt.plot(storagew[:,0]/86400,storagew[:,8],'y',marker = 'o',markersize = 11)

#plt.plot(storage[:,0]/86400,storage[:,15],'c--',marker = '^',markersize = 11)
#plt.plot(storage[:,0]/86400,storage[:,16],'y--',marker = '^',markersize = 11)

#plt.plot(qstorage[:,0]/86400,qstorage[:,15],'c-.',marker = '*',markersize = 11)
#plt.plot(qstorage[:,0]/86400,qstorage[:,16],'y-.',marker = '*',markersize = 11)


#plt.xlim(45000,1e6)
#plt.ylim(0,6)
plt.xlabel('Time (days)', fontsize = 20, fontweight = 'bold')
plt.ylabel('Flow Rate (kg/s)', fontsize = 20, fontweight = 'bold')
plt.title('Flow Rate vs. Time (5 kg/s) (One Fracture Model)',fontsize = 20, fontweight = 'bold')
#plt.legend(['Inlet With Both Perfs','Outlet With Both Perfs','Inlet Without Exit Perfs','Outlet Without Exit Perfs','Inlet Without Any Perfs','Outlet Without Any Perfs'], fontsize = 20)
plt.grid(which='major', axis='both',color='lightgrey',zorder=1)
fig.savefig(r'%s/1fracmodelTHMmasscheck.png' %path, bbox_inches='tight')

# %%
fig = plt.figure(1)
ax = fig.gca()
for axis in [ax.xaxis, ax.yaxis]:
    axis.set_major_locator(ticker.MaxNLocator(integer=True))
fig.set_figwidth(18)
fig.set_figheight(18)

plt.plot(storagew[:,0]/86400,storagew[:,11],'c',marker = 'o',markersize = 11)
plt.plot(storagew[:,0]/86400,storagew[:,12],'c--',marker = '^',markersize = 11)
#plt.plot(qstorage[:,0]/86400,qstorage[:,23],'c-.',marker = '*',markersize = 11)

#plt.plot(storagew[:,0]/86400,storagew[:,25],'y',marker = 'o',markersize = 11)
#plt.plot(storage[:,0]/86400,storage[:,25],'y--',marker = '^',markersize = 11)
#plt.plot(qstorage[:,0]/86400,qstorage[:,25],'y-.',marker = '*',markersize = 11)

#plt.plot(storagew[:,0]/86400,storagew[:,27],'m',marker = 'o',markersize = 11)
#plt.plot(storage[:,0]/86400,storage[:,27],'m--',marker = '^',markersize = 11)
#plt.plot(qstorage[:,0]/86400,qstorage[:,27],'m-.',marker = '*',markersize = 11)



#plt.xlim(45000,1e6)
#plt.ylim(-0.3e-10,0.1e-9)
plt.xlabel('Time (days)', fontsize = 20, fontweight = 'bold')
plt.ylabel('Permeability (m^2)', fontsize = 20, fontweight = 'bold')
plt.title('Permeability vs. Time (5 kg/s) (One Fracture Model)',fontsize = 20, fontweight = 'bold')
plt.legend(['Fracture3 Inlet','Fracture3 Outlet'], fontsize = 20)
plt.grid(which='major', axis='both',color='lightgrey',zorder=1)
fig.savefig(r'%s/1fracmodelTHMpermeability.png' %path, bbox_inches='tight')

# %%
fig = plt.figure(1)
ax = fig.gca()
for axis in [ax.xaxis, ax.yaxis]:
    axis.set_major_locator(ticker.MaxNLocator(integer=True))
fig.set_figwidth(18)
fig.set_figheight(18)

plt.plot(storagew[:,0]/86400,storagew[:,14],'c',marker = 'o',markersize = 11)
#plt.plot(storage[:,0]/86400,storage[:,30],'c--',marker = '^',markersize = 11)
#plt.plot(qstorage[:,0]/86400,qstorage[:,30],'c-.',marker = '*',markersize = 11)

#plt.plot(storagew[:,0]/86400,storagew[:,31],'y',marker = 'o',markersize = 11)
#plt.plot(storage[:,0]/86400,storage[:,31],'y--',marker = '^',markersize = 11)
#plt.plot(qstorage[:,0]/86400,qstorage[:,31],'y-.',marker = '*',markersize = 11)

#plt.plot(storagew[:,0]/86400,storagew[:,32],'m',marker = 'o',markersize = 11)
#plt.plot(storage[:,0]/86400,storage[:,32],'m--',marker = '^',markersize = 11)
#plt.plot(qstorage[:,0]/86400,qstorage[:,32],'m-.',marker = '*',markersize = 11)




#plt.xlim(45000,1e6)
#plt.ylim(0,100)
plt.xlabel('Time (days)', fontsize = 20, fontweight = 'bold')
plt.ylabel('Pressure Drop (PSI)', fontsize = 20, fontweight = 'bold')
plt.title('Pressure Drop vs. Time (5 kg/s) (One Fracture Model)',fontsize = 20, fontweight = 'bold')
#plt.legend(['Fracture1 With Both Perfs','Fracture1 Without Exit Perfs','Fracture1 Without Any Perfs','Fracture2 With Both Perfs','Fracture2 Without Exit Perfs','Fracture2 Without Any Perfs','Fracture3 With Both Perfs','Fracture3 Without Exit Perfs','Fracture3 Without Any Perfs'], fontsize = 20)
plt.grid(which='major', axis='both',color='lightgrey',zorder=1)
fig.savefig(r'%s/1fracmodelTHMdeltaPfractures.png' %path, bbox_inches='tight')

# %%
fig = plt.figure(1)
ax = fig.gca()
for axis in [ax.xaxis, ax.yaxis]:
    axis.set_major_locator(ticker.MaxNLocator(integer=True))
fig.set_figwidth(18)
fig.set_figheight(18)




plt.plot(storagew[:,0]/86400,storagew[:,2]-273.15,'m',marker = 'o',markersize = 11)
plt.plot(storagew[:,0]/86400,storagew[:,3]-273.15,'m--',marker = '^',markersize = 11)
#plt.plot(storage[:,0]/86400,storage[:,4]-273.15,'y',marker = 'o',markersize = 11)
#plt.plot(storage[:,0]/86400,storage[:,5]-273.15,'y--',marker = '^',markersize = 11)
#plt.plot(storage[:,0]/86400,storage[:,6]-273.15,'m',marker = 'o',markersize = 11)
#plt.plot(storage[:,0]/86400,storage[:,7]-273.15,'m--',marker = '^',markersize = 11)








#plt.xlim(45000,1e6)
#plt.ylim(0,6)
plt.xlabel('Time (days)', fontsize = 20, fontweight = 'bold')
plt.ylabel('Temperature (°C)', fontsize = 20, fontweight = 'bold')
plt.title('Temperature vs. Time (5 kg/s) (One Fracture Model)',fontsize = 20, fontweight = 'bold')
plt.legend(['Fracture3 Inlet','Fracture3 Outlet'], fontsize = 20)
plt.grid(which='major', axis='both',color='lightgrey',zorder=1)
fig.savefig(r'%s/1fracmodelTHMtemp.png' %path, bbox_inches='tight')

# %%
fig = plt.figure(1)
ax = fig.gca()
for axis in [ax.xaxis, ax.yaxis]:
    axis.set_major_locator(ticker.MaxNLocator(integer=True))
fig.set_figwidth(18)
fig.set_figheight(18)

plt.plot(storagew[:,0]/86400,storagew[:,20],'r',marker = 'o',markersize = 11)


#plt.xlim(0,31)
#plt.ylim(0,2000)
plt.xlabel('Time (days)', fontsize = 20, fontweight = 'bold')
plt.ylabel('Exit Velocity (m/s)', fontsize = 20, fontweight = 'bold')
plt.title('Exit Velocity vs. Time (5 kg/s) (One Fracture Model)',fontsize = 20, fontweight = 'bold')
#plt.legend(['Injection Pressure','Production Pressure'], fontsize = 20)
plt.grid(which='major', axis='both',color='lightgrey',zorder=1)
fig.savefig(r'%s/1fracmodelTHMRe.png' %path, bbox_inches='tight')

# %%
pwo = pd.read_csv('1fracmodel_CSV_injection_pipe_p_0158.csv')
pwo2 = pd.DataFrame(pwo)
injection = pwo2.to_numpy()
print(np.shape(injection))

pwoa = pd.read_csv('1fracmodel_CSV_pipe2_p_0158.csv')
pwo2a = pd.DataFrame(pwoa)
pipe2 = pwo2a.to_numpy()

pwoa574bcq = pd.read_csv('1fracmodel_CSV_fracture3_perf1_p_0158.csv')
pwo2a574bcq = pd.DataFrame(pwoa574bcq)
frac3_perf1 = pwo2a574bcq.to_numpy()

pwoa574bc = pd.read_csv('1fracmodel_CSV_fracture3_p_0158.csv')
pwo2a574bc = pd.DataFrame(pwoa574bc)
frac3 = pwo2a574bc.to_numpy()

pwoa574bcq2 = pd.read_csv('1fracmodel_CSV_fracture3_perf2_p_0158.csv')
pwo2a574bcq2 = pd.DataFrame(pwoa574bcq2)
frac3_perf2 = pwo2a574bcq2.to_numpy()

pwob = pd.read_csv('1fracmodel_CSV_pipe3_p_0158.csv')
pwo2b = pd.DataFrame(pwob)
pipe3 = pwo2b.to_numpy()

pwoc = pd.read_csv('1fracmodel_CSV_pipe4_p_0158.csv')
pwo2c = pd.DataFrame(pwoc)
pipe4 = pwo2c.to_numpy()

pwod = pd.read_csv('1fracmodel_CSV_pipe5_p_0158.csv')
pwo2d = pd.DataFrame(pwod)
pipe5 = pwo2d.to_numpy()

pwoe = pd.read_csv('1fracmodel_CSV_pipe6_p_0158.csv')
pwo2e = pd.DataFrame(pwoe)
pipe6 = pwo2e.to_numpy()

pwoe3 = pd.read_csv('1fracmodel_CSV_pipe7_p_0158.csv')
pwo2e3 = pd.DataFrame(pwoe3)
pipe7 = pwo2e3.to_numpy()

pwoz = pd.read_csv('1fracmodel_CSV_production_pipe_p_0158.csv')
pwo2z = pd.DataFrame(pwoz)
production = pwo2z.to_numpy()
# Out:
# (200, 5)

# %%
fig = plt.figure(1)

matplotlib.rcParams.update({'font.size': 20})
matplotlib.rcParams.update({'font.weight': 'bold'})
ax = fig.gca()
for axis in [ax.xaxis, ax.yaxis]:
    axis.set_major_locator(ticker.MaxNLocator(integer=True))
fig.set_figwidth(18)
fig.set_figheight(18)

plt.plot(injection[:,0],(injection[:,1]/1e6)*145.038,'r',marker = 'o',markersize = 11)
plt.plot(2057+pipe2[:,0],(pipe2[:,1]/1e6)*145.038,'b',marker = 'o',markersize = 11)

plt.plot(2057+1030.624+pipe3[:,0],(pipe3[:,1]/1e6)*145.038,'g',marker = 'o',markersize = 11)


plt.plot(2057+1030.624+134.11199999999977579826999+pipe4[:,0],(pipe4[:,1]/1e6)*145.038,'y',marker = 'o',markersize = 11)




#plt.xlim(0,31)
#plt.ylim(4800,5400)
plt.xlabel('Length (m)', fontsize = 20, fontweight = 'bold')
plt.ylabel('Pressure (PSI)', fontsize = 20, fontweight = 'bold')
plt.title('Length vs. Pressure (~= 11 days) (5 kg/s) (One Fracture Model)',fontsize = 20, fontweight = 'bold')
plt.legend(['Injection Pipe','pipe2','pipe3','pipe4'], fontsize = 20)
plt.grid(which='major', axis='both',color='lightgrey',zorder=1)
fig.savefig(r'%s/1fracmodelInjectionP.png' %path, bbox_inches='tight')

# %%
fig = plt.figure(1)

matplotlib.rcParams.update({'font.size': 20})
matplotlib.rcParams.update({'font.weight': 'bold'})
ax = fig.gca()
for axis in [ax.xaxis, ax.yaxis]:
    axis.set_major_locator(ticker.MaxNLocator(integer=True))
fig.set_figwidth(18)
fig.set_figheight(18)

plt.plot(injection[:,0],(injection[:,1]/1e6)*145.038,'r',marker = 'o',markersize = 11)
plt.plot(2057+pipe2[:,0],(pipe2[:,1]/1e6)*145.038,'b',marker = 'o',markersize = 11)
plt.plot(2057+1030.624+pipe3[:,0],(pipe3[:,1]/1e6)*145.038,'g',marker = 'o',markersize = 11)
plt.plot(2057+1030.624+134.11199999999977579826999+pipe4[:,0],(pipe4[:,1]/1e6)*145.038,'c',marker = 'o',markersize = 11)
plt.plot(2057+1030.624+134.11199999999977579826999+96.6216000000002242017300066403672380476882366854447151848085862086006951628994154778073990218053823121593587821581875667170042568+frac3_perf1[:,0],(frac3_perf1[:,1]/1e6)*145.038,'m',marker = 'o',markersize = 11)
plt.plot(2057+1030.624+134.11199999999977579826999+96.6216000000002242017300066403672380476882366854447151848085862086006951628994154778073990218053823121593587821581875667170042568+1+frac3[:,0],(frac3[:,1]/1e6)*145.038,color = '0.8',marker = 'o',markersize = 11)
plt.plot(2057+1030.624+134.11199999999977579826999+96.6216000000002242017300066403672380476882366854447151848085862086006951628994154778073990218053823121593587821581875667170042568+1+98.1617127018392107082677912904102391759840600506092245079207843746364902370741653573756231075282759892565263907571110035070651488+frac3_perf2[:,0],(frac3_perf2[:,1]/1e6)*145.038,color = 'y',marker = 'o',markersize = 11)
plt.plot(2057+1030.624+134.11199999999977579826999+96.6216000000002242017300066403672380476882366854447151848085862086006951628994154778073990218053823121593587821581875667170042568+1+98.1617127018392107082677912904102391759840600506092245079207843746364902370741653573756231075282759892565263907571110035070651488+1+pipe5[:,0],(pipe5[:,1]/1e6)*145.038,color = 'k',marker = 'o',markersize = 11)
plt.plot(2057+1030.624+134.11199999999977579826999+96.6216000000002242017300066403672380476882366854447151848085862086006951628994154778073990218053823121593587821581875667170042568+1+98.1617127018392107082677912904102391759840600506092245079207843746364902370741653573756231075282759892565263907571110035070651488+1+95.98796573232744884430750078506290102503278647382158534085570989394969673954105727357396694128582740674997664529042836849765532463+pipe6[:,0],(pipe6[:,1]/1e6)*145.038,'g--',marker = '^',markersize = 11)
plt.plot(2057+1030.624+134.11199999999977579826999+96.6216000000002242017300066403672380476882366854447151848085862086006951628994154778073990218053823121593587821581875667170042568+1+98.1617127018392107082677912904102391759840600506092245079207843746364902370741653573756231075282759892565263907571110035070651488+1+95.98796573232744884430750078506290102503278647382158534085570989394969673954105727357396694128582740674997664529042836849765532463+134.3831520254032945149806604022249511373686265222140310267294357738408632051396721890210394615420535395791672387625071589120847354+pipe7[:,0],(pipe7[:,1]/1e6)*145.038,'b--',marker = '^',markersize = 11)
plt.plot(2057+1030.624+134.11199999999977579826999+96.6216000000002242017300066403672380476882366854447151848085862086006951628994154778073990218053823121593587821581875667170042568+1+98.1617127018392107082677912904102391759840600506092245079207843746364902370741653573756231075282759892565263907571110035070651488+1+95.98796573232744884430750078506290102503278647382158534085570989394969673954105727357396694128582740674997664529042836849765532463+134.3831520254032945149806604022249511373686265222140310267294357738408632051396721890210394615420535395791672387625071589120847354+1029.8137466431315497906037378549111856734274905914330325658709398128891119815951012845583455723940079060997436706937542731921405+production[:,0],(production[:,1]/1e6)*145.038,'r--',marker = '^',markersize = 11)


#plt.xlim(0,31)
#plt.ylim(4800,5400)
plt.xlabel('Length (m)', fontsize = 20, fontweight = 'bold')
plt.ylabel('Pressure (PSI)', fontsize = 20, fontweight = 'bold')
plt.title('Length vs. Pressure (~= 11 days) (5 kg/s) (One Fracture Model)',fontsize = 20, fontweight = 'bold')
plt.legend(['Injection Pipe','pipe2','pipe3','pipe4','fracture3_perf1','fracture3','fracture3_perf2','pipe5','pipe6','pipe7','Production Pipe'], fontsize = 20)
plt.grid(which='major', axis='both',color='lightgrey',zorder=1)
fig.savefig(r'%s/1fracmodelTHMlengthfrac3.png' %path, bbox_inches='tight')
